# %%
import os
import shutil

# %%
#directory = os.listdir(".")
directory = os.listdir("/Users/eneskaranfil/Desktop/Dataset/Pothole_Video/")

# %%
directory
# Out:
# ['frame10240.jpg',
#  'frame4966.jpg',
#  'frame19502.jpg',
#  'frame16631.jpg',
#  'frame15338.jpg',
#  'frame583.jpg',
#  'frame13991.jpg',
#  'frame12457.jpg',
#  'frame8184.jpg',
#  'frame13749.jpg',
#  'frame14026.jpg',
#  'frame3990.xml',
#  'frame14740.jpg',
#  'frame6817.jpg',
#  'frame14998.jpg',
#  'frame12331.jpg',
#  'frame19264.jpg',
#  'frame16157.jpg',
#  'frame11638.jpg',
#  'frame10526.jpg',
#  'frame17249.jpg',
#  'frame19270.jpg',
#  'frame16143.jpg',
#  'frame10532.jpg',
#  'frame14754.jpg',
#  'frame6803.jpg',
#  'frame12325.jpg',
#  'frame597.jpg',
#  'frame13985.jpg',
#  'frame12443.jpg',
#  'frame8190.jpg',
#  'frame14032.jpg',
#  'frame18608.jpg',
#  'frame10254.jpg',
#  'frame19516.jpg',
#  'frame4972.jpg',
#  'frame16625.jpg',
#  'frame15304.jpg',
#  'frame6195.jpg',
#  'frame13775.jpg',
#  'frame1822.jpg',
#  'frame17513.jpg',
#  'frame18620.jpg',
#  'frame4782.jpg',
#  'frame226.xml',
#  'frame11162.jpg',
#  'frame7512.xml',
#  'frame2495.jpg',
# ...

# %%
xml_file = []
for index in directory:
    if index.endswith("xml"):
        xml_file.append(index)
        
jpg_file = []
for index in directory:
    if index.endswith("jpg"):
        jpg_file.append(index)

# %%
type(xml_file)
# Out:
# list

# %%
xml_file.sort()
len(xml_file)
# Out:
# 416

# %%
jpg_file.sort()

# %%
for i in jpg_file:
    for j in xml_file:
        if i[:i.index(".")] == j[:j.index(".")]:
            shutil.move("/Users/eneskaranfil/Desktop/Dataset/Pothole_Video/"+i,"/Users/eneskaranfil/Desktop/Pothole Data/İmages")
            #shutil.move("/Users/eneskaranfil/Desktop/Dataset/Pothole_Video/"+j,"/Users/eneskaranfil/Desktop/Pothole Data/Annot")

# %%
r1 = os.listdir("/Users/eneskaranfil/Desktop/Pothole Data/Annot")
r2 = os.listdir("/Users/eneskaranfil/Desktop/Pothole Data/İmages")
print("Total Dataset Size",len(r1)) # 196 from Internet 416 from video
print(len(r2))
# Out:
# Total Dataset Size 612
# 612

# %%
for i in directory:
    for j in directory:
        if i[:i.index(".")] == j[:j.index(".")] and i != j:
            print(i)
            print(j)
# Out:
# p 239.jpg
# p 239.xml
# p 239.xml
# p 239.jpg
# p 210.xml
# p 210.jpg
# p 238.xml
# p 238.jpg
# p 238.jpg
# p 238.xml
# p 210.jpg
# p 210.xml
# p 206.jpg
# p 206.xml
# p 206.xml
# p 206.jpg
# p 207.xml
# p 207.jpg
# p 213.xml
# p 213.jpg
# p 207.jpg
# p 207.xml
# p 213.jpg
# p 213.xml
# p 217.jpg
# p 217.xml
# p 203.jpg
# p 203.xml
# p 217.xml
# p 217.jpg
# p 203.xml
# p 203.jpg
# .DS_Store
# .ipynb_checkpoints
# p 216.xml
# p 216.jpg
# p 216.jpg
# p 216.xml
# p 228.jpg
# p 228.xml
# p 228.xml
# p 228.jpg
# p 348.jpg
# p 348.xml
# p 348.xml
# p 348.jpg
# p 349.xml
# p 349.jpg
# p 349.jpg
# p 349.xml
# p 215.xml
# p 215.jpg
# p 215.jpg
# p 215.xml
# p 266.jpg
# p 266.xml
# p 272.jpg
# p 272.xml
# p 266.xml
# p 266.jpg
# p 272.xml
# p 272.jpg
# p 312.jpg
# p 312.xml
# p 312.xml
# p 312.jpg
# p 313.xml
# p 313.jpg
# p 313.jpg
# p 313.xml
# p 259.jpg
# p 259.xml
# p 259.xml
# p 259.jpg
# p 339.jpg
# p 339.xml
# p 339.xml
# p 339.jpg
# p 310.xml
# p 310.jpg
# p 304.xml
# p 304.jpg
# ...
